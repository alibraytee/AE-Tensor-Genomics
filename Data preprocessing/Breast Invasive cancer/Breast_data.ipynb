# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#reading data into dataframe
scnv = pd.read_table('Human__TCGA_BRCA__BI__SCNA__SNP_6.0__01_28_2016__BI__Focal__Firehose_GISTIC2.cct')
miRNASeq = pd.read_table('Human__TCGA_BRCA__BDGSC__miRNASeq__HS_miR__01_28_2016__BI__Gene__Firehose_RPKM_log2.cct')
clinical = pd.read_table('Human__TCGA_BRCA__MS__Clinical__Clinical__01_28_2016__BI__Clinical__Firehose.tsi')
rnaSeq = pd.read_table('Human__TCGA_BRCA__UNC__RNAseq__HiSeq_RNA__01_28_2016__BI__Gene__Firehose_RSEM_log2.cct')
methylation = pd.read_table('Human__TCGA_BRCA__JHU_USC__Methylation__Meth450__01_28_2016__BI__CpG__Firehose_Methylation_Prepocessor.cct')
# RNAseq
# clinical
# miRNASeq
# scna_data

# %%
# transpose all dataframe and update headers

#1080 rows × 69 columns
scnv_t = scnv.T
scnv_t = scnv_t[1:]
scnv_t.columns = scnv['attrib_name']
#755 rows × 823 columns
miRNASeq_t = miRNASeq.T
miRNASeq_t = miRNASeq_t[1:]
miRNASeq_t.columns = miRNASeq['attrib_name']
#1093 rows × 20155 columns
rnaSeq_t = rnaSeq.T
rnaSeq_t = rnaSeq_t[1:]
rnaSeq_t.columns = rnaSeq['attrib_name']
#783 rows × 335854 columns
methylation_t = methylation.T
methylation_t = methylation_t[1:]
methylation_t.columns = methylation['attrib_name']

#1097 rows × 20 columns
clinical_t = clinical.T
clinical_t = clinical_t[1:]
clinical_t.columns = clinical['attrib_name']

# %%
# scnv_t
# miRNASeq_t
clinical_t
# rnaSeq_t
# methylation_t
# Out:
# attrib_name  years_to_birth Tumor_purity pathologic_stage pathology_T_stage  \
# TCGA.5L.AAT0             42       0.6501          stageii                t2
# TCGA.5L.AAT1             63       0.5553          stageiv                t2
# TCGA.A1.A0SP             40       0.6913          stageii                t2
# TCGA.A2.A04V             39       0.8341          stageii                t2
# TCGA.A2.A04Y             53       0.7318          stageii                t2
# ...                     ...          ...              ...               ...
# TCGA.V7.A7HQ             75       0.7774         stageiii                t1
# TCGA.WT.AB44            NaN       0.7493           stagei                t1
# TCGA.XX.A899             46       0.6069         stageiii                t1
# TCGA.XX.A89A             68       0.6067          stageii                t3
# TCGA.Z7.A8R6             46       0.8143           stagei                t1
#
# attrib_name  pathology_N_stage pathology_M_stage  \
# TCGA.5L.AAT0                n0                m0
# TCGA.5L.AAT1                n0                m1
# TCGA.A1.A0SP                n0                m0
# TCGA.A2.A04V                n0                m0
# TCGA.A2.A04Y                n1                m0
# ...                        ...               ...
# TCGA.V7.A7HQ                n2                m0
# TCGA.WT.AB44                n0               NaN
# TCGA.XX.A899                n2               NaN
# TCGA.XX.A89A                n0               NaN
# TCGA.Z7.A8R6                n0                m0
#
# attrib_name              histological_type number_of_lymph_nodes  PAM50  \
# TCGA.5L.AAT0  infiltratinglobularcarcinoma                     0    NaN
# TCGA.5L.AAT1  infiltratinglobularcarcinoma                     0    NaN
# TCGA.A1.A0SP   infiltratingductalcarcinoma                     0  Basal
# TCGA.A2.A04V   infiltratingductalcarcinoma                     0   LumA
# TCGA.A2.A04Y   infiltratingductalcarcinoma                     1   LumB
# ...                                    ...                   ...    ...
# TCGA.V7.A7HQ   infiltratingductalcarcinoma                     5    NaN
# TCGA.WT.AB44  infiltratinglobularcarcinoma                     0    NaN
# TCGA.XX.A899  infiltratinglobularcarcinoma                     5    NaN
# TCGA.XX.A89A  infiltratinglobularcarcinoma                     0    NaN
# TCGA.Z7.A8R6  infiltratinglobularcarcinoma                     0    NaN
#
# attrib_name  ER.Status PR.Status HER2.Status  gender radiation_therapy  \
# TCGA.5L.AAT0       NaN       NaN         NaN  female               yes
# TCGA.5L.AAT1       NaN       NaN         NaN  female                no
# TCGA.A1.A0SP       NaN       NaN         NaN  female               NaN
# TCGA.A2.A04V       NaN       NaN         NaN  female                no
# TCGA.A2.A04Y       NaN       NaN         NaN  female               yes
# ...                ...       ...         ...     ...               ...
# TCGA.V7.A7HQ       NaN       NaN         NaN  female               yes
# TCGA.WT.AB44       NaN       NaN         NaN  female               yes
# TCGA.XX.A899       NaN       NaN         NaN  female               yes
# TCGA.XX.A89A       NaN       NaN         NaN  female               yes
# TCGA.Z7.A8R6       NaN       NaN         NaN  female                no
#
# attrib_name                     race            ethnicity  \
# TCGA.5L.AAT0                   white     hispanicorlatino
# TCGA.5L.AAT1                   white     hispanicorlatino
# TCGA.A1.A0SP                     NaN  nothispanicorlatino
# TCGA.A2.A04V                   white  nothispanicorlatino
# TCGA.A2.A04Y                   white                  NaN
# ...                              ...                  ...
# TCGA.V7.A7HQ  blackorafricanamerican  nothispanicorlatino
# TCGA.WT.AB44                   white  nothispanicorlatino
# TCGA.XX.A899                   white  nothispanicorlatino
# TCGA.XX.A89A                   white  nothispanicorlatino
# TCGA.Z7.A8R6                   white  nothispanicorlatino
#
# attrib_name  Median_overall_survival overall_survival status overallsurvival
# TCGA.5L.AAT0                       0             1477      0          1477,0
# TCGA.5L.AAT1                       0             1471      0          1471,0
# TCGA.A1.A0SP                       0              584      0           584,0
# TCGA.A2.A04V                       0             1920      1          1920,1
# TCGA.A2.A04Y                       0             1099      0          1099,0
# ...                              ...              ...    ...             ...
# TCGA.V7.A7HQ                       0             2033      0          2033,0
# TCGA.WT.AB44                       0              883      0           883,0
# TCGA.XX.A899                       0              467      0           467,0
# TCGA.XX.A89A                       0              488      0           488,0
# TCGA.Z7.A8R6                       0             3256      0          3256,0
#
# [1097 rows x 20 columns]

# %%
#scnv_t.index
result = miRNASeq_t.join(methylation_t, how="inner")# 755, 783
result
# Out:
# attrib_name  hsa-let-7a-1 hsa-let-7a-2 hsa-let-7a-3 hsa-let-7b hsa-let-7c  \
# TCGA.3C.AAAU      13.1299       14.118      13.1479    14.5952     8.4191
# TCGA.3C.AALI      12.9183      13.9224      12.9134    14.5127     9.6483
# TCGA.3C.AALJ      13.0122      14.0101      13.0287    13.4197     9.3147
# TCGA.3C.AALK      13.1449      14.1418      13.1514    14.6673    11.5119
# TCGA.4H.AAAK      13.4118      14.4136      13.4206    14.4386    11.6944
# ...                   ...          ...          ...        ...        ...
# TCGA.WT.AB44      13.3759      14.3667        13.37    14.5141    11.9267
# TCGA.XX.A899      14.0362      15.0364      14.0434    14.3396     12.362
# TCGA.XX.A89A      13.6797      14.6849      13.6916    14.1983    12.6844
# TCGA.Z7.A8R5      12.9623      13.9664      12.9851    14.3207    11.9806
# TCGA.Z7.A8R6      13.3498        14.35      13.3786    14.1173    10.3791
#
# attrib_name  hsa-let-7d hsa-let-7e hsa-let-7f-1 hsa-let-7f-2 hsa-let-7g  ...  \
# TCGA.3C.AAAU     8.6695    10.5228       3.9742      11.8252     8.6015  ...
# TCGA.3C.AALI     9.0065     9.1343       4.4543      12.6791     8.4592  ...
# TCGA.3C.AALJ     9.2793    11.3962       5.3505      13.5304      9.233  ...
# TCGA.3C.AALK     8.3891    10.3701       4.2378      12.6528     8.4756  ...
# TCGA.4H.AAAK     8.4579    10.7422       4.5572      13.0097     8.3855  ...
# ...                 ...        ...          ...          ...        ...  ...
# TCGA.WT.AB44     8.5241    10.5369        4.609      13.3679     9.1616  ...
# TCGA.XX.A899      7.663    11.0863       5.2437      14.1539      9.767  ...
# TCGA.XX.A89A     8.5569    11.3152       4.8829      14.0395     9.6062  ...
# TCGA.Z7.A8R5     8.2123     9.9116       4.6372      12.8967     8.7462  ...
# TCGA.Z7.A8R6     9.6291    10.9321       4.9526       13.417     9.1771  ...
#
# attrib_name  SNORD67_ch.11.967412F CKAP5_ch.11.967412F TRIM13_ch.13.693633F  \
# TCGA.3C.AAAU               -0.4559             -0.4559              -0.4028
# TCGA.3C.AALI               -0.4415             -0.4415              -0.4285
# TCGA.3C.AALJ               -0.4513             -0.4513              -0.4385
# TCGA.3C.AALK               -0.4249             -0.4249              -0.4334
# TCGA.4H.AAAK               -0.4505             -0.4505              -0.4371
# ...                            ...                 ...                  ...
# TCGA.WT.AB44                -0.435              -0.435              -0.4347
# TCGA.XX.A899               -0.4692             -0.4692              -0.4626
# TCGA.XX.A89A               -0.4649             -0.4649              -0.4553
# TCGA.Z7.A8R5               -0.4446             -0.4446              -0.4463
# TCGA.Z7.A8R6               -0.4804             -0.4804              -0.4647
#
# attrib_name  DLEU2_ch.13.693633F EIF4G1_ch.3.3596501R SNORD66_ch.3.3596501R  \
# TCGA.3C.AAAU             -0.4028                  NaN                   NaN
# TCGA.3C.AALI             -0.4285              -0.3486               -0.3486
# TCGA.3C.AALJ             -0.4385                  NaN                   NaN
# TCGA.3C.AALK             -0.4334                  NaN                   NaN
# TCGA.4H.AAAK             -0.4371              -0.3418               -0.3418
# ...                          ...                  ...                   ...
# TCGA.WT.AB44             -0.4347              -0.2876               -0.2876
# TCGA.XX.A899             -0.4626              -0.3647               -0.3647
# TCGA.XX.A89A             -0.4553              -0.3859               -0.3859
# TCGA.Z7.A8R5             -0.4463                  NaN                   NaN
# TCGA.Z7.A8R6             -0.4647              -0.3531               -0.3531
#
# attrib_name  FAM13B_ch.5.2533205R PKD2L2_ch.5.2533205R HNRNPK_ch.9.1116984R  \
# TCGA.3C.AAAU                  NaN                  NaN                  NaN
# TCGA.3C.AALI                  NaN                  NaN                  NaN
# TCGA.3C.AALJ                  NaN                  NaN                  NaN
# TCGA.3C.AALK                  NaN                  NaN                  NaN
# TCGA.4H.AAAK                  NaN                  NaN                  NaN
# ...                           ...                  ...                  ...
# TCGA.WT.AB44                  NaN                  NaN                  NaN
# TCGA.XX.A899               -0.374               -0.374              -0.2598
# TCGA.XX.A89A              -0.3756              -0.3756               -0.247
# TCGA.Z7.A8R5                  NaN                  NaN                  NaN
# TCGA.Z7.A8R6              -0.4356              -0.4356              -0.4183
#
# attrib_name  MIR7-1_ch.9.1116984R
# TCGA.3C.AAAU                  NaN
# TCGA.3C.AALI                  NaN
# TCGA.3C.AALJ                  NaN
# TCGA.3C.AALK                  NaN
# TCGA.4H.AAAK                  NaN
# ...                           ...
# TCGA.WT.AB44                  NaN
# TCGA.XX.A899              -0.2598
# TCGA.XX.A89A               -0.247
# TCGA.Z7.A8R5                  NaN
# TCGA.Z7.A8R6              -0.4183
#
# [623 rows x 336677 columns]

# %%
result2 = result.join(scnv_t, how="inner") # 623, 1080
result2
# Out:
# attrib_name  hsa-let-7a-1 hsa-let-7a-2 hsa-let-7a-3 hsa-let-7b hsa-let-7c  \
# TCGA.3C.AAAU      13.1299       14.118      13.1479    14.5952     8.4191
# TCGA.3C.AALI      12.9183      13.9224      12.9134    14.5127     9.6483
# TCGA.3C.AALJ      13.0122      14.0101      13.0287    13.4197     9.3147
# TCGA.3C.AALK      13.1449      14.1418      13.1514    14.6673    11.5119
# TCGA.4H.AAAK      13.4118      14.4136      13.4206    14.4386    11.6944
# ...                   ...          ...          ...        ...        ...
# TCGA.WT.AB44      13.3759      14.3667        13.37    14.5141    11.9267
# TCGA.XX.A899      14.0362      15.0364      14.0434    14.3396     12.362
# TCGA.XX.A89A      13.6797      14.6849      13.6916    14.1983    12.6844
# TCGA.Z7.A8R5      12.9623      13.9664      12.9851    14.3207    11.9806
# TCGA.Z7.A8R6      13.3498        14.35      13.3786    14.1173    10.3791
#
# attrib_name  hsa-let-7d hsa-let-7e hsa-let-7f-1 hsa-let-7f-2 hsa-let-7g  ...  \
# TCGA.3C.AAAU     8.6695    10.5228       3.9742      11.8252     8.6015  ...
# TCGA.3C.AALI     9.0065     9.1343       4.4543      12.6791     8.4592  ...
# TCGA.3C.AALJ     9.2793    11.3962       5.3505      13.5304      9.233  ...
# TCGA.3C.AALK     8.3891    10.3701       4.2378      12.6528     8.4756  ...
# TCGA.4H.AAAK     8.4579    10.7422       4.5572      13.0097     8.3855  ...
# ...                 ...        ...          ...          ...        ...  ...
# TCGA.WT.AB44     8.5241    10.5369        4.609      13.3679     9.1616  ...
# TCGA.XX.A899      7.663    11.0863       5.2437      14.1539      9.767  ...
# TCGA.XX.A89A     8.5569    11.3152       4.8829      14.0395     9.6062  ...
# TCGA.Z7.A8R5     8.2123     9.9116       4.6372      12.8967     8.7462  ...
# TCGA.Z7.A8R6     9.6291    10.9321       4.9526       13.417     9.1771  ...
#
# attrib_name  16q24.3  17p12    17q21.31 18q23    19p13.3  19q13.32 20p13     \
# TCGA.3C.AAAU   0.1227  -0.5673   0.0783   0.2153        0        0   0.7256
# TCGA.3C.AALI   0.0316  -0.5252  -0.5345  -0.9387  -0.1543   0.0964   0.8302
# TCGA.3C.AALJ   0.0085  -0.6944  -0.6702   0.1714  -0.3152   0.0053   0.0199
# TCGA.3C.AALK  -0.6359   -0.644  -0.6406  -0.0121  -0.0168  -0.0314   0.0316
# TCGA.4H.AAAK  -0.6684  -0.6687    0.289   0.0134  -0.7006   0.2952   0.0303
# ...               ...      ...      ...      ...      ...      ...      ...
# TCGA.WT.AB44   -0.741   -0.183  -0.2027  -0.1635   -0.227   -0.227  -0.2252
# TCGA.XX.A899  -0.3495   0.0083   0.0083  -0.0086  -0.0003  -0.0003   0.0025
# TCGA.XX.A89A  -0.5178  -0.5123  -0.5123  -0.5264  -0.4909   0.0624    0.032
# TCGA.Z7.A8R5  -0.1828   0.0089   0.0089    0.005   0.0086   0.0086   0.0113
# TCGA.Z7.A8R6    -0.82  -0.7681   0.0307  -0.0222  -0.0603  -0.0603    0.669
#
# attrib_name  21q11.2  22q11.1  22q13.32
# TCGA.3C.AAAU   0.9069  -0.5961  -0.5961
# TCGA.3C.AALI  -0.4325  -0.0728  -0.4906
# TCGA.3C.AALJ  -0.3309  -0.6947  -0.6923
# TCGA.3C.AALK  -0.0527   0.0195   0.0195
# TCGA.4H.AAAK  -0.0135  -0.0278   0.0128
# ...               ...      ...      ...
# TCGA.WT.AB44   0.0493   0.3462   -0.715
# TCGA.XX.A899   0.0049   0.0153   0.0085
# TCGA.XX.A89A   0.0129  -0.5039   -0.508
# TCGA.Z7.A8R5   0.0008   -0.148   -0.148
# TCGA.Z7.A8R6  -0.0532  -0.0685  -0.0685
#
# [618 rows x 336746 columns]

# %%
result3 = result2.join(rnaSeq_t, how="inner")
result3
# Out:
# attrib_name  hsa-let-7a-1 hsa-let-7a-2 hsa-let-7a-3 hsa-let-7b hsa-let-7c  \
# TCGA.3C.AAAU      13.1299       14.118      13.1479    14.5952     8.4191
# TCGA.3C.AALI      12.9183      13.9224      12.9134    14.5127     9.6483
# TCGA.3C.AALJ      13.0122      14.0101      13.0287    13.4197     9.3147
# TCGA.3C.AALK      13.1449      14.1418      13.1514    14.6673    11.5119
# TCGA.4H.AAAK      13.4118      14.4136      13.4206    14.4386    11.6944
# ...                   ...          ...          ...        ...        ...
# TCGA.WT.AB44      13.3759      14.3667        13.37    14.5141    11.9267
# TCGA.XX.A899      14.0362      15.0364      14.0434    14.3396     12.362
# TCGA.XX.A89A      13.6797      14.6849      13.6916    14.1983    12.6844
# TCGA.Z7.A8R5      12.9623      13.9664      12.9851    14.3207    11.9806
# TCGA.Z7.A8R6      13.3498        14.35      13.3786    14.1173    10.3791
#
# attrib_name  hsa-let-7d hsa-let-7e hsa-let-7f-1 hsa-let-7f-2 hsa-let-7g  ...  \
# TCGA.3C.AAAU     8.6695    10.5228       3.9742      11.8252     8.6015  ...
# TCGA.3C.AALI     9.0065     9.1343       4.4543      12.6791     8.4592  ...
# TCGA.3C.AALJ     9.2793    11.3962       5.3505      13.5304      9.233  ...
# TCGA.3C.AALK     8.3891    10.3701       4.2378      12.6528     8.4756  ...
# TCGA.4H.AAAK     8.4579    10.7422       4.5572      13.0097     8.3855  ...
# ...                 ...        ...          ...          ...        ...  ...
# TCGA.WT.AB44     8.5241    10.5369        4.609      13.3679     9.1616  ...
# TCGA.XX.A899      7.663    11.0863       5.2437      14.1539      9.767  ...
# TCGA.XX.A89A     8.5569    11.3152       4.8829      14.0395     9.6062  ...
# TCGA.Z7.A8R5     8.2123     9.9116       4.6372      12.8967     8.7462  ...
# TCGA.Z7.A8R6     9.6291    10.9321       4.9526       13.417     9.1771  ...
#
# attrib_name     ZXDA    ZXDB     ZXDC  ZYG11A  ZYG11B      ZYX    ZZEF1  \
# TCGA.3C.AAAU  7.0289  9.9784  10.6965  8.0196   10.24  11.7765  10.8887
# TCGA.3C.AALI  5.9264  8.8125  10.3924  7.6401  9.2398  12.4267  10.3659
# TCGA.3C.AALJ  5.1842  9.0634   9.5884  8.3786  9.0585  12.4146   9.8825
# TCGA.3C.AALK   5.808  8.7772   9.7564  7.4629  9.2488  12.4748   9.6113
# TCGA.4H.AAAK   5.642  8.7322  10.0373   3.911  9.6013  11.9811    9.702
# ...              ...     ...      ...     ...     ...      ...      ...
# TCGA.WT.AB44  4.6687  7.9339   9.5961  6.6374  8.3047  13.4171   9.6468
# TCGA.XX.A899  6.1672  9.3325  10.3078  4.4764  9.4288  12.3217   10.918
# TCGA.XX.A89A  5.6338    8.42  10.4268  7.3697  9.5465  12.4196  10.4903
# TCGA.Z7.A8R5  5.0555  7.9628   9.6388   5.727  8.9856  12.7049   9.5611
# TCGA.Z7.A8R6  5.1477    8.61   9.8901  7.1348  9.1661  11.7328   9.1432
#
# attrib_name      ZZZ3 psiTPTE22    tAKR
# TCGA.3C.AAAU  10.2064    1.4454       0
# TCGA.3C.AALI   8.6715    9.8573       0
# TCGA.3C.AALJ   8.9958    5.1842       0
# TCGA.3C.AALK   9.4551    6.0792       0
# TCGA.4H.AAAK   9.7858    7.5564       0
# ...               ...       ...     ...
# TCGA.WT.AB44   8.7947    9.5036       0
# TCGA.XX.A899   9.3903    6.6355       0
# TCGA.XX.A89A   9.8989    7.8841  0.9595
# TCGA.Z7.A8R5   9.5543    7.9065       0
# TCGA.Z7.A8R6   8.8552    4.4514       0
#
# [616 rows x 356901 columns]

# %%
result_final = result3.join(clinical_t, how="inner")
result_final
# Out:
# attrib_name  hsa-let-7a-1 hsa-let-7a-2 hsa-let-7a-3 hsa-let-7b hsa-let-7c  \
# TCGA.3C.AAAU      13.1299       14.118      13.1479    14.5952     8.4191
# TCGA.3C.AALI      12.9183      13.9224      12.9134    14.5127     9.6483
# TCGA.3C.AALJ      13.0122      14.0101      13.0287    13.4197     9.3147
# TCGA.3C.AALK      13.1449      14.1418      13.1514    14.6673    11.5119
# TCGA.4H.AAAK      13.4118      14.4136      13.4206    14.4386    11.6944
# ...                   ...          ...          ...        ...        ...
# TCGA.WT.AB44      13.3759      14.3667        13.37    14.5141    11.9267
# TCGA.XX.A899      14.0362      15.0364      14.0434    14.3396     12.362
# TCGA.XX.A89A      13.6797      14.6849      13.6916    14.1983    12.6844
# TCGA.Z7.A8R5      12.9623      13.9664      12.9851    14.3207    11.9806
# TCGA.Z7.A8R6      13.3498        14.35      13.3786    14.1173    10.3791
#
# attrib_name  hsa-let-7d hsa-let-7e hsa-let-7f-1 hsa-let-7f-2 hsa-let-7g  ...  \
# TCGA.3C.AAAU     8.6695    10.5228       3.9742      11.8252     8.6015  ...
# TCGA.3C.AALI     9.0065     9.1343       4.4543      12.6791     8.4592  ...
# TCGA.3C.AALJ     9.2793    11.3962       5.3505      13.5304      9.233  ...
# TCGA.3C.AALK     8.3891    10.3701       4.2378      12.6528     8.4756  ...
# TCGA.4H.AAAK     8.4579    10.7422       4.5572      13.0097     8.3855  ...
# ...                 ...        ...          ...          ...        ...  ...
# TCGA.WT.AB44     8.5241    10.5369        4.609      13.3679     9.1616  ...
# TCGA.XX.A899      7.663    11.0863       5.2437      14.1539      9.767  ...
# TCGA.XX.A89A     8.5569    11.3152       4.8829      14.0395     9.6062  ...
# TCGA.Z7.A8R5     8.2123     9.9116       4.6372      12.8967     8.7462  ...
# TCGA.Z7.A8R6     9.6291    10.9321       4.9526       13.417     9.1771  ...
#
# attrib_name  PR.Status HER2.Status  gender radiation_therapy  \
# TCGA.3C.AAAU       NaN         NaN  female                no
# TCGA.3C.AALI       NaN         NaN  female               yes
# TCGA.3C.AALJ       NaN         NaN  female                no
# TCGA.3C.AALK       NaN         NaN  female                no
# TCGA.4H.AAAK       NaN         NaN  female                no
# ...                ...         ...     ...               ...
# TCGA.WT.AB44       NaN         NaN  female               yes
# TCGA.XX.A899       NaN         NaN  female               yes
# TCGA.XX.A89A       NaN         NaN  female               yes
# TCGA.Z7.A8R5       NaN         NaN  female                no
# TCGA.Z7.A8R6       NaN         NaN  female                no
#
# attrib_name                     race            ethnicity  \
# TCGA.3C.AAAU                   white  nothispanicorlatino
# TCGA.3C.AALI  blackorafricanamerican  nothispanicorlatino
# TCGA.3C.AALJ  blackorafricanamerican  nothispanicorlatino
# TCGA.3C.AALK  blackorafricanamerican  nothispanicorlatino
# TCGA.4H.AAAK                   white  nothispanicorlatino
# ...                              ...                  ...
# TCGA.WT.AB44                   white  nothispanicorlatino
# TCGA.XX.A899                   white  nothispanicorlatino
# TCGA.XX.A89A                   white  nothispanicorlatino
# TCGA.Z7.A8R5                   white  nothispanicorlatino
# TCGA.Z7.A8R6                   white  nothispanicorlatino
#
# attrib_name  Median_overall_survival overall_survival status overallsurvival
# TCGA.3C.AAAU                       1             4047      0          4047,0
# TCGA.3C.AALI                       1             4005      0          4005,0
# TCGA.3C.AALJ                       0             1474      0          1474,0
# TCGA.3C.AALK                       0             1448      0          1448,0
# TCGA.4H.AAAK                       0              348      0           348,0
# ...                              ...              ...    ...             ...
# TCGA.WT.AB44                       0              883      0           883,0
# TCGA.XX.A899                       0              467      0           467,0
# TCGA.XX.A89A                       0              488      0           488,0
# TCGA.Z7.A8R5                       0             3287      0          3287,0
# TCGA.Z7.A8R6                       0             3256      0          3256,0
#
# [616 rows x 356921 columns]
